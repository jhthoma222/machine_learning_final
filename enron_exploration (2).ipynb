# %%
# %load poi_id.py
#!/usr/bin/python

import sys
import pickle
sys.path.append("D:/Desktop/WGU Projects/data_analyst_nanodegree/machine_learning/ud120-projects-master/tools/")

from feature_format import featureFormat, targetFeatureSplit
from tester import dump_classifier_and_data


### Task 1: Select what features you'll use.
### features_list is a list of strings, each of which is a feature name.
### The first feature must be "poi".
features_list = ['poi','salary'] # You will need to use more features

### Load the dictionary containing the dataset
with open("D:/Desktop/WGU Projects/data_analyst_nanodegree/machine_learning/ud120-projects-master/final_project/final_project_dataset.pkl", "r") as data_file:
    data_dict = pickle.load(data_file)

### Task 2: Remove outliers
### Task 3: Create new feature(s)
### Store to my_dataset for easy export below.
my_dataset = data_dict

### Extract features and labels from dataset for local testing
data = featureFormat(my_dataset, features_list, sort_keys = True)
labels, features = targetFeatureSplit(data)

### Task 4: Try a varity of classifiers
### Please name your classifier clf for easy export below.
### Note that if you want to do PCA or other multi-stage operations,
### you'll need to use Pipelines. For more info:
### http://scikit-learn.org/stable/modules/pipeline.html

# Provided to give you a starting point. Try a variety of classifiers.
from sklearn.naive_bayes import GaussianNB
clf = GaussianNB()

### Task 5: Tune your classifier to achieve better than .3 precision and recall 
### using our testing script. Check the tester.py script in the final project
### folder for details on the evaluation method, especially the test_classifier
### function. Because of the small size of the dataset, the script uses
### stratified shuffle split cross validation. For more info: 
### http://scikit-learn.org/stable/modules/generated/sklearn.cross_validation.StratifiedShuffleSplit.html

# Example starting point. Try investigating other evaluation techniques!
from sklearn.model_selection import train_test_split
features_train, features_test, labels_train, labels_test = \
    train_test_split(features, labels, test_size=0.3, random_state=42)

### Task 6: Dump your classifier, dataset, and features_list so anyone can
### check your results. You do not need to change anything below, but make sure
### that the version of poi_id.py that you submit can be run on its own and
### generates the necessary .pkl files for validating your results.

dump_classifier_and_data(clf, my_dataset, features_list)

# %%
enron_data = my_dataset
print 'Length of data: ', len(enron_data)
print 'Number of Features: ' + str(len(enron_data[my_dataset.keys()[0]]))
# Out:
# Length of data:  146
# Number of Features: 21

# %%
# Count POIs
count = 0
for person_name in enron_data:
    if enron_data[person_name]["poi"] == True:
        count+=1
print count
# Out:
# 18

# %%
for person_name in enron_data:
    if enron_data[person_name]["poi"] == True:
        print [person_name]
# Out:
# ['HANNON KEVIN P']
# ['COLWELL WESLEY']
# ['RIEKER PAULA H']
# ['KOPPER MICHAEL J']
# ['SHELBY REX']
# ['DELAINEY DAVID W']
# ['LAY KENNETH L']
# ['BOWEN JR RAYMOND M']
# ['BELDEN TIMOTHY N']
# ['FASTOW ANDREW S']
# ['CALGER CHRISTOPHER F']
# ['RICE KENNETH D']
# ['SKILLING JEFFREY K']
# ['YEAGER F SCOTT']
# ['HIRKO JOSEPH']
# ['KOENIG MARK E']
# ['CAUSEY RICHARD A']
# ['GLISAN JR BEN F']

# %%
print enron_data["SKILLING JEFFREY K"]
# Out:
# {'salary': 1111258, 'to_messages': 3627, 'deferral_payments': 'NaN', 'total_payments': 8682716, 'exercised_stock_options': 19250000, 'bonus': 5600000, 'restricted_stock': 6843672, 'shared_receipt_with_poi': 2042, 'restricted_stock_deferred': 'NaN', 'total_stock_value': 26093672, 'expenses': 29336, 'loan_advances': 'NaN', 'from_messages': 108, 'other': 22122, 'from_this_person_to_poi': 30, 'poi': True, 'director_fees': 'NaN', 'deferred_income': 'NaN', 'long_term_incentive': 1920000, 'email_address': 'jeff.skilling@enron.com', 'from_poi_to_this_person': 88}

# %%
#Plotting Bonus vs Salary, Checking for the outliers

features = ["salary", "bonus"]

data = featureFormat(data_dict, features)

for point in data:
    salary = point[0]
    bonus = point[1]
    plt.scatter( salary, bonus )

plt.xlabel("salary")
plt.ylabel("bonus")
# Out:
# Text(0,0.5,'bonus')

# %%
### Removed 'Total'
features = ["salary", "bonus"]
data_dict.pop('TOTAL', 0)
data = featureFormat(data_dict, features)

# %%
#Plotting Bonus vs Salary, Checking for the outliers

features = ["salary", "bonus"]

data = featureFormat(data_dict, features)

for point in data:
    salary = point[0]
    bonus = point[1]
    plt.scatter( salary, bonus )

plt.xlabel("salary")
plt.ylabel("bonus")
# Out:
# Text(0,0.5,'bonus')

# %%
# Bonus Outliers

from pprint import pprint
bonus_outliers = []
for key in enron_data:
    val = enron_data[key]['bonus']
    if val == 'NaN':
        continue
    bonus_outliers.append((key,int(val)))

pprint(sorted(bonus_outliers,key=lambda x:x[1],reverse=True)[:2])
# Out:
# [('LAVORATO JOHN J', 8000000), ('LAY KENNETH L', 7000000)]

# %%
# Salary Outliers

salary_outliers = []
for key in enron_data:
    val = enron_data[key]['salary']
    if val == 'NaN':
        continue
    salary_outliers.append((key,int(val)))

pprint(sorted(salary_outliers,key=lambda x:x[1],reverse=True)[:2])
# Out:
# [('SKILLING JEFFREY K', 1111258), ('LAY KENNETH L', 1072321)]

# %%
#Plotting from person to POI vs. from POI to person, Checking for the outliers
import matplotlib.pyplot

features = ["from_this_person_to_poi", "from_poi_to_this_person"]
data = featureFormat(enron_data, features)


### your code below
print data.max()
for point in data:
    from_this_person_to_poi = point[0]
    from_poi_to_this_person = point[1]
    matplotlib.pyplot.scatter( from_this_person_to_poi, from_poi_to_this_person )

matplotlib.pyplot.xlabel("from_this_person_to_poi")
matplotlib.pyplot.ylabel("from_poi_to_this_person")
matplotlib.pyplot.show()
# Out:
# 609.0

# %%
#To POI outliers

to_poi_outliers = []
for key in enron_data:
    val = enron_data[key]['from_this_person_to_poi']
    if val == 'NaN':
        continue
    to_poi_outliers.append((key,int(val)))

pprint(sorted(to_poi_outliers,key=lambda x:x[1],reverse=True)[:2])
# Out:
# [('DELAINEY DAVID W', 609), ('LAVORATO JOHN J', 411)]

# %%
#From POI to Outliers

from_poi_outliers = []
for key in enron_data:
    val = enron_data[key]['from_poi_to_this_person']
    if val == 'NaN':
        continue
    from_poi_outliers.append((key,int(val)))

pprint(sorted(from_poi_outliers,key=lambda x:x[1],reverse=True)[:2])
# Out:
# [('LAVORATO JOHN J', 528), ('DIETRICH JANET R', 305)]

# %%
#Wanted to explore using pandas
import pandas as pd

enron_df = pd.DataFrame(data_dict)
enron_df = enron_df.T
enron_df
# Out:
#                                  bonus deferral_payments deferred_income  \
# ALLEN PHILLIP K                4175000           2869717        -3081055
# BADUM JAMES P                      NaN            178980             NaN
# BANNANTINE JAMES M                 NaN               NaN           -5104
# BAXTER JOHN C                  1200000           1295738        -1386055
# BAY FRANKLIN R                  400000            260455         -201641
# BAZELIDES PHILIP J                 NaN            684694             NaN
# BECK SALLY W                    700000               NaN             NaN
# BELDEN TIMOTHY N               5249999           2144013        -2334434
# BELFER ROBERT                      NaN           -102500             NaN
# BERBERIAN DAVID                    NaN               NaN             NaN
# BERGSIEKER RICHARD P            250000               NaN         -485813
# BHATNAGAR SANJAY                   NaN               NaN             NaN
# BIBI PHILIPPE A                1000000               NaN             NaN
# BLACHMAN JEREMY M               850000               NaN             NaN
# BLAKE JR. NORMAN P                 NaN               NaN         -113784
# BOWEN JR RAYMOND M             1350000               NaN            -833
# BROWN MICHAEL                      NaN               NaN             NaN
# BUCHANAN HAROLD G               500000               NaN             NaN
# BUTTS ROBERT H                  750000               NaN          -75000
# BUY RICHARD B                   900000            649584         -694862
# CALGER CHRISTOPHER F           1250000               NaN         -262500
# CARTER REBECCA C                300000               NaN         -159792
# CAUSEY RICHARD A               1000000               NaN         -235000
# CHAN RONNIE                        NaN               NaN          -98784
# CHRISTODOULOU DIOMEDES             NaN               NaN             NaN
# CLINE KENNETH W                    NaN               NaN             NaN
# COLWELL WESLEY                 1200000             27610         -144062
# CORDES WILLIAM R                   NaN               NaN             NaN
# COX DAVID                       800000               NaN          -41250
# CUMBERLAND MICHAEL S            325000               NaN             NaN
# ...                                ...               ...             ...
# SCRIMSHAW MATTHEW                  NaN               NaN             NaN
# SHANKMAN JEFFREY A             2000000               NaN             NaN
# SHAPIRO RICHARD S               650000               NaN             NaN
# SHARP VICTORIA T                600000            187469             NaN
# SHELBY REX                      200000               NaN           -4167
# SHERRICK JEFFREY B                 NaN               NaN             NaN
# SHERRIFF JOHN R                1500000               NaN             NaN
# SKILLING JEFFREY K             5600000               NaN             NaN
# STABLER FRANK                   500000               NaN             NaN
# SULLIVAN-SHAKLOVITZ COLLEEN     100000            181993             NaN
# SUNDE MARTIN                    700000               NaN             NaN
# TAYLOR MITCHELL S               600000            227449             NaN
# THE TRAVEL AGENCY IN THE PARK      NaN               NaN             NaN
# THORN TERENCE H                    NaN             16586             NaN
# TILNEY ELIZABETH A              300000               NaN         -575000
# UMANOFF ADAM S                  788750               NaN             NaN
# URQUHART JOHN A                    NaN               NaN          -36666
# WAKEHAM JOHN                       NaN               NaN             NaN
# WALLS JR ROBERT H               850000               NaN             NaN
# WALTERS GARETH W                   NaN             53625             NaN
# WASAFF GEORGE                   325000            831299         -583325
# WESTFAHL RICHARD K                 NaN               NaN          -10800
# WHALEY DAVID A                     NaN               NaN             NaN
# WHALLEY LAWRENCE G             3000000               NaN             NaN
# WHITE JR THOMAS E               450000               NaN             NaN
# WINOKUR JR. HERBERT S              NaN               NaN          -25000
# WODRASKA JOHN                      NaN               NaN             NaN
# WROBEL BRUCE                       NaN               NaN             NaN
# YEAGER F SCOTT                     NaN               NaN             NaN
# YEAP SOON                          NaN               NaN             NaN
#
#                               director_fees                     email_address  \
# ALLEN PHILLIP K                         NaN           phillip.allen@enron.com
# BADUM JAMES P                           NaN                               NaN
# BANNANTINE JAMES M                      NaN        james.bannantine@enron.com
# BAXTER JOHN C                           NaN                               NaN
# BAY FRANKLIN R                          NaN               frank.bay@enron.com
# BAZELIDES PHILIP J                      NaN                               NaN
# BECK SALLY W                            NaN              sally.beck@enron.com
# BELDEN TIMOTHY N                        NaN              tim.belden@enron.com
# BELFER ROBERT                          3285                               NaN
# BERBERIAN DAVID                         NaN         david.berberian@enron.com
# BERGSIEKER RICHARD P                    NaN         rick.bergsieker@enron.com
# BHATNAGAR SANJAY                     137864        sanjay.bhatnagar@enron.com
# BIBI PHILIPPE A                         NaN           philippe.bibi@enron.com
# BLACHMAN JEREMY M                       NaN         jeremy.blachman@enron.com
# BLAKE JR. NORMAN P                   113784                               NaN
# BOWEN JR RAYMOND M                      NaN           raymond.bowen@enron.com
# BROWN MICHAEL                           NaN           michael.brown@enron.com
# BUCHANAN HAROLD G                       NaN           john.buchanan@enron.com
# BUTTS ROBERT H                          NaN               bob.butts@enron.com
# BUY RICHARD B                           NaN                rick.buy@enron.com
# CALGER CHRISTOPHER F                    NaN      christopher.calger@enron.com
# CARTER REBECCA C                        NaN          rebecca.carter@enron.com
# CAUSEY RICHARD A                        NaN          richard.causey@enron.com
# CHAN RONNIE                           98784                               NaN
# CHRISTODOULOU DIOMEDES                  NaN  diomedes.christodoulou@enron.com
# CLINE KENNETH W                         NaN                               NaN
# COLWELL WESLEY                          NaN             wes.colwell@enron.com
# CORDES WILLIAM R                        NaN             bill.cordes@enron.com
# COX DAVID                               NaN                chip.cox@enron.com
# CUMBERLAND MICHAEL S                    NaN                               NaN
# ...                                     ...                               ...
# SCRIMSHAW MATTHEW                       NaN       matthew.scrimshaw@enron.com
# SHANKMAN JEFFREY A                      NaN        jeffrey.shankman@enron.com
# SHAPIRO RICHARD S                       NaN         richard.shapiro@enron.com
# SHARP VICTORIA T                        NaN             vicki.sharp@enron.com
# SHELBY REX                              NaN              rex.shelby@enron.com
# SHERRICK JEFFREY B                      NaN        jeffrey.sherrick@enron.com
# SHERRIFF JOHN R                         NaN           john.sherriff@enron.com
# SKILLING JEFFREY K                      NaN           jeff.skilling@enron.com
# STABLER FRANK                           NaN           frank.stabler@enron.com
# SULLIVAN-SHAKLOVITZ COLLEEN             NaN                               NaN
# SUNDE MARTIN                            NaN             marty.sunde@enron.com
# TAYLOR MITCHELL S                       NaN         mitchell.taylor@enron.com
# THE TRAVEL AGENCY IN THE PARK           NaN                               NaN
# THORN TERENCE H                         NaN           terence.thorn@enron.com
# TILNEY ELIZABETH A                      NaN        elizabeth.tilney@enron.com
# UMANOFF ADAM S                          NaN            adam.umanoff@enron.com
# URQUHART JOHN A                       36666                               NaN
# WAKEHAM JOHN                         109298                               NaN
# WALLS JR ROBERT H                       NaN               rob.walls@enron.com
# WALTERS GARETH W                        NaN                               NaN
# WASAFF GEORGE                           NaN           george.wasaff@enron.com
# WESTFAHL RICHARD K                      NaN           dick.westfahl@enron.com
# WHALEY DAVID A                          NaN                               NaN
# WHALLEY LAWRENCE G                      NaN            greg.whalley@enron.com
# WHITE JR THOMAS E                       NaN            thomas.white@enron.com
# WINOKUR JR. HERBERT S                108579                               NaN
# WODRASKA JOHN                           NaN           john.wodraska@enron.com
# WROBEL BRUCE                            NaN                               NaN
# YEAGER F SCOTT                          NaN            scott.yeager@enron.com
# YEAP SOON                               NaN                               NaN
#
#                               exercised_stock_options expenses from_messages  \
# ALLEN PHILLIP K                               1729541    13868          2195
# BADUM JAMES P                                  257817     3486           NaN
# BANNANTINE JAMES M                            4046157    56301            29
# BAXTER JOHN C                                 6680544    11200           NaN
# BAY FRANKLIN R                                    NaN   129142           NaN
# BAZELIDES PHILIP J                            1599641      NaN           NaN
# BECK SALLY W                                      NaN    37172          4343
# BELDEN TIMOTHY N                               953136    17355           484
# BELFER ROBERT                                    3285      NaN           NaN
# BERBERIAN DAVID                               1624396    11892           NaN
# BERGSIEKER RICHARD P                              NaN    59175            59
# BHATNAGAR SANJAY                              2604490      NaN            29
# BIBI PHILIPPE A                               1465734    38559            40
# BLACHMAN JEREMY M                              765313    84208            14
# BLAKE JR. NORMAN P                                NaN     1279           NaN
# BOWEN JR RAYMOND M                                NaN    65907            27
# BROWN MICHAEL                                     NaN    49288            41
# BUCHANAN HAROLD G                              825464      600           125
# BUTTS ROBERT H                                    NaN     9410           NaN
# BUY RICHARD B                                 2542813      NaN          1053
# CALGER CHRISTOPHER F                              NaN    35818           144
# CARTER REBECCA C                                  NaN      NaN            15
# CAUSEY RICHARD A                                  NaN    30674            49
# CHAN RONNIE                                       NaN      NaN           NaN
# CHRISTODOULOU DIOMEDES                        5127155      NaN           NaN
# CLINE KENNETH W                                   NaN      NaN           NaN
# COLWELL WESLEY                                    NaN    16514            40
# CORDES WILLIAM R                               651850      NaN            12
# COX DAVID                                      117551    27861            33
# CUMBERLAND MICHAEL S                              NaN    22344           NaN
# ...                                               ...      ...           ...
# SCRIMSHAW MATTHEW                              759557      NaN           NaN
# SHANKMAN JEFFREY A                            1441898   178979          2681
# SHAPIRO RICHARD S                              607837   137767          1215
# SHARP VICTORIA T                               281073   116337           136
# SHELBY REX                                    1624396    22884            39
# SHERRICK JEFFREY B                            1426469      NaN            25
# SHERRIFF JOHN R                               1835558      NaN            92
# SKILLING JEFFREY K                           19250000    29336           108
# STABLER FRANK                                     NaN    16514           NaN
# SULLIVAN-SHAKLOVITZ COLLEEN                   1362375      NaN           NaN
# SUNDE MARTIN                                      NaN      NaN            38
# TAYLOR MITCHELL S                             3181250      NaN            29
# THE TRAVEL AGENCY IN THE PARK                     NaN      NaN           NaN
# THORN TERENCE H                               4452476    46145            41
# TILNEY ELIZABETH A                             591250      NaN            19
# UMANOFF ADAM S                                    NaN    53122            18
# URQUHART JOHN A                                   NaN   228656           NaN
# WAKEHAM JOHN                                      NaN   103773           NaN
# WALLS JR ROBERT H                             4346544    50936           146
# WALTERS GARETH W                              1030329    33785           NaN
# WASAFF GEORGE                                 1668260      NaN            30
# WESTFAHL RICHARD K                                NaN    51870           NaN
# WHALEY DAVID A                                  98718      NaN           NaN
# WHALLEY LAWRENCE G                            3282960    57838           556
# WHITE JR THOMAS E                             1297049    81353           NaN
# WINOKUR JR. HERBERT S                             NaN     1413           NaN
# WODRASKA JOHN                                     NaN      NaN           NaN
# WROBEL BRUCE                                   139130      NaN           NaN
# YEAGER F SCOTT                                8308552    53947           NaN
# YEAP SOON                                      192758    55097           NaN
#
#                               from_poi_to_this_person from_this_person_to_poi  \
# ALLEN PHILLIP K                                    47                      65
# BADUM JAMES P                                     NaN                     NaN
# BANNANTINE JAMES M                                 39                       0
# BAXTER JOHN C                                     NaN                     NaN
# BAY FRANKLIN R                                    NaN                     NaN
# BAZELIDES PHILIP J                                NaN                     NaN
# BECK SALLY W                                      144                     386
# BELDEN TIMOTHY N                                  228                     108
# BELFER ROBERT                                     NaN                     NaN
# BERBERIAN DAVID                                   NaN                     NaN
# BERGSIEKER RICHARD P                                4                       0
# BHATNAGAR SANJAY                                    0                       1
# BIBI PHILIPPE A                                    23                       8
# BLACHMAN JEREMY M                                  25                       2
# BLAKE JR. NORMAN P                                NaN                     NaN
# BOWEN JR RAYMOND M                                140                      15
# BROWN MICHAEL                                      13                       1
# BUCHANAN HAROLD G                                   0                       0
# BUTTS ROBERT H                                    NaN                     NaN
# BUY RICHARD B                                     156                      71
# CALGER CHRISTOPHER F                              199                      25
# CARTER REBECCA C                                   29                       7
# CAUSEY RICHARD A                                   58                      12
# CHAN RONNIE                                       NaN                     NaN
# CHRISTODOULOU DIOMEDES                            NaN                     NaN
# CLINE KENNETH W                                   NaN                     NaN
# COLWELL WESLEY                                    240                      11
# CORDES WILLIAM R                                   10                       0
# COX DAVID                                           0                       4
# CUMBERLAND MICHAEL S                              NaN                     NaN
# ...                                               ...                     ...
# SCRIMSHAW MATTHEW                                 NaN                     NaN
# SHANKMAN JEFFREY A                                 94                      83
# SHAPIRO RICHARD S                                  74                      65
# SHARP VICTORIA T                                   24                       6
# SHELBY REX                                         13                      14
# SHERRICK JEFFREY B                                 39                      18
# SHERRIFF JOHN R                                    28                      23
# SKILLING JEFFREY K                                 88                      30
# STABLER FRANK                                     NaN                     NaN
# SULLIVAN-SHAKLOVITZ COLLEEN                       NaN                     NaN
# SUNDE MARTIN                                       37                      13
# TAYLOR MITCHELL S                                   0                       0
# THE TRAVEL AGENCY IN THE PARK                     NaN                     NaN
# THORN TERENCE H                                     0                       0
# TILNEY ELIZABETH A                                 10                      11
# UMANOFF ADAM S                                     12                       0
# URQUHART JOHN A                                   NaN                     NaN
# WAKEHAM JOHN                                      NaN                     NaN
# WALLS JR ROBERT H                                  17                       0
# WALTERS GARETH W                                  NaN                     NaN
# WASAFF GEORGE                                      22                       7
# WESTFAHL RICHARD K                                NaN                     NaN
# WHALEY DAVID A                                    NaN                     NaN
# WHALLEY LAWRENCE G                                186                      24
# WHITE JR THOMAS E                                 NaN                     NaN
# WINOKUR JR. HERBERT S                             NaN                     NaN
# WODRASKA JOHN                                     NaN                     NaN
# WROBEL BRUCE                                      NaN                     NaN
# YEAGER F SCOTT                                    NaN                     NaN
# YEAP SOON                                         NaN                     NaN
#
#                                ... long_term_incentive    other    poi  \
# ALLEN PHILLIP K                ...              304805      152  False
# BADUM JAMES P                  ...                 NaN      NaN  False
# BANNANTINE JAMES M             ...                 NaN   864523  False
# BAXTER JOHN C                  ...             1586055  2660303  False
# BAY FRANKLIN R                 ...                 NaN       69  False
# BAZELIDES PHILIP J             ...               93750      874  False
# BECK SALLY W                   ...                 NaN      566  False
# BELDEN TIMOTHY N               ...                 NaN   210698   True
# BELFER ROBERT                  ...                 NaN      NaN  False
# BERBERIAN DAVID                ...                 NaN      NaN  False
# BERGSIEKER RICHARD P           ...              180250   427316  False
# BHATNAGAR SANJAY               ...                 NaN   137864  False
# BIBI PHILIPPE A                ...              369721   425688  False
# BLACHMAN JEREMY M              ...              831809      272  False
# BLAKE JR. NORMAN P             ...                 NaN      NaN  False
# BOWEN JR RAYMOND M             ...              974293     1621   True
# BROWN MICHAEL                  ...                 NaN      NaN  False
# BUCHANAN HAROLD G              ...              304805     1215  False
# BUTTS ROBERT H                 ...              175000   150656  False
# BUY RICHARD B                  ...              769862   400572  False
# CALGER CHRISTOPHER F           ...              375304      486   True
# CARTER REBECCA C               ...               75000      540  False
# CAUSEY RICHARD A               ...              350000   307895   True
# CHAN RONNIE                    ...                 NaN      NaN  False
# CHRISTODOULOU DIOMEDES         ...                 NaN      NaN  False
# CLINE KENNETH W                ...                 NaN      NaN  False
# COLWELL WESLEY                 ...                 NaN   101740   True
# CORDES WILLIAM R               ...                 NaN      NaN  False
# COX DAVID                      ...                 NaN      494  False
# CUMBERLAND MICHAEL S           ...              275000      713  False
# ...                            ...                 ...      ...    ...
# SCRIMSHAW MATTHEW              ...                 NaN      NaN  False
# SHANKMAN JEFFREY A             ...              554422     1191  False
# SHAPIRO RICHARD S              ...                 NaN      705  False
# SHARP VICTORIA T               ...              422158     2401  False
# SHELBY REX                     ...                 NaN  1573324   True
# SHERRICK JEFFREY B             ...                 NaN      NaN  False
# SHERRIFF JOHN R                ...              554422  1852186  False
# SKILLING JEFFREY K             ...             1920000    22122   True
# STABLER FRANK                  ...                 NaN   356071  False
# SULLIVAN-SHAKLOVITZ COLLEEN    ...              554422      162  False
# SUNDE MARTIN                   ...              476451   111122  False
# TAYLOR MITCHELL S              ...                 NaN      NaN  False
# THE TRAVEL AGENCY IN THE PARK  ...                 NaN   362096  False
# THORN TERENCE H                ...              200000   426629  False
# TILNEY ELIZABETH A             ...              275000   152055  False
# UMANOFF ADAM S                 ...                 NaN      NaN  False
# URQUHART JOHN A                ...                 NaN      NaN  False
# WAKEHAM JOHN                   ...                 NaN      NaN  False
# WALLS JR ROBERT H              ...              540751        2  False
# WALTERS GARETH W               ...                 NaN      NaN  False
# WASAFF GEORGE                  ...              200000     1425  False
# WESTFAHL RICHARD K             ...              256191   401130  False
# WHALEY DAVID A                 ...                 NaN      NaN  False
# WHALLEY LAWRENCE G             ...              808346   301026  False
# WHITE JR THOMAS E              ...                 NaN  1085463  False
# WINOKUR JR. HERBERT S          ...                 NaN      NaN  False
# WODRASKA JOHN                  ...                 NaN   189583  False
# WROBEL BRUCE                   ...                 NaN      NaN  False
# YEAGER F SCOTT                 ...                 NaN   147950   True
# YEAP SOON                      ...                 NaN      NaN  False
#
#                               restricted_stock restricted_stock_deferred  \
# ALLEN PHILLIP K                         126027                   -126027
# BADUM JAMES P                              NaN                       NaN
# BANNANTINE JAMES M                     1757552                   -560222
# BAXTER JOHN C                          3942714                       NaN
# BAY FRANKLIN R                          145796                    -82782
# BAZELIDES PHILIP J                         NaN                       NaN
# BECK SALLY W                            126027                       NaN
# BELDEN TIMOTHY N                        157569                       NaN
# BELFER ROBERT                              NaN                     44093
# BERBERIAN DAVID                         869220                       NaN
# BERGSIEKER RICHARD P                    659249                       NaN
# BHATNAGAR SANJAY                      -2604490                  15456290
# BIBI PHILIPPE A                         378082                       NaN
# BLACHMAN JEREMY M                       189041                       NaN
# BLAKE JR. NORMAN P                         NaN                       NaN
# BOWEN JR RAYMOND M                      252055                       NaN
# BROWN MICHAEL                              NaN                       NaN
# BUCHANAN HAROLD G                       189041                       NaN
# BUTTS ROBERT H                          417619                       NaN
# BUY RICHARD B                           901657                       NaN
# CALGER CHRISTOPHER F                    126027                       NaN
# CARTER REBECCA C                        307301                   -307301
# CAUSEY RICHARD A                       2502063                       NaN
# CHAN RONNIE                              32460                    -32460
# CHRISTODOULOU DIOMEDES                  950730                       NaN
# CLINE KENNETH W                         662086                   -472568
# COLWELL WESLEY                          698242                       NaN
# CORDES WILLIAM R                        386335                       NaN
# COX DAVID                               378082                       NaN
# CUMBERLAND MICHAEL S                    207940                       NaN
# ...                                        ...                       ...
# SCRIMSHAW MATTHEW                          NaN                       NaN
# SHANKMAN JEFFREY A                      630137                       NaN
# SHAPIRO RICHARD S                       379164                       NaN
# SHARP VICTORIA T                        213063                       NaN
# SHELBY REX                              869220                       NaN
# SHERRICK JEFFREY B                      405999                       NaN
# SHERRIFF JOHN R                        1293424                       NaN
# SKILLING JEFFREY K                     6843672                       NaN
# STABLER FRANK                           511734                       NaN
# SULLIVAN-SHAKLOVITZ COLLEEN                NaN                       NaN
# SUNDE MARTIN                            698920                       NaN
# TAYLOR MITCHELL S                       563798                       NaN
# THE TRAVEL AGENCY IN THE PARK              NaN                       NaN
# THORN TERENCE H                         365320                       NaN
# TILNEY ELIZABETH A                      576792                       NaN
# UMANOFF ADAM S                             NaN                       NaN
# URQUHART JOHN A                            NaN                       NaN
# WAKEHAM JOHN                               NaN                       NaN
# WALLS JR ROBERT H                      1552453                       NaN
# WALTERS GARETH W                           NaN                       NaN
# WASAFF GEORGE                           388167                       NaN
# WESTFAHL RICHARD K                      384930                       NaN
# WHALEY DAVID A                             NaN                       NaN
# WHALLEY LAWRENCE G                     2796177                       NaN
# WHITE JR THOMAS E                     13847074                       NaN
# WINOKUR JR. HERBERT S                      NaN                       NaN
# WODRASKA JOHN                              NaN                       NaN
# WROBEL BRUCE                               NaN                       NaN
# YEAGER F SCOTT                         3576206                       NaN
# YEAP SOON                                  NaN                       NaN
#
#                                 salary shared_receipt_with_poi to_messages  \
# ALLEN PHILLIP K                 201955                    1407        2902
# BADUM JAMES P                      NaN                     NaN         NaN
# BANNANTINE JAMES M                 477                     465         566
# BAXTER JOHN C                   267102                     NaN         NaN
# BAY FRANKLIN R                  239671                     NaN         NaN
# BAZELIDES PHILIP J               80818                     NaN         NaN
# BECK SALLY W                    231330                    2639        7315
# BELDEN TIMOTHY N                213999                    5521        7991
# BELFER ROBERT                      NaN                     NaN         NaN
# BERBERIAN DAVID                 216582                     NaN         NaN
# BERGSIEKER RICHARD P            187922                     233         383
# BHATNAGAR SANJAY                   NaN                     463         523
# BIBI PHILIPPE A                 213625                    1336        1607
# BLACHMAN JEREMY M               248546                    2326        2475
# BLAKE JR. NORMAN P                 NaN                     NaN         NaN
# BOWEN JR RAYMOND M              278601                    1593        1858
# BROWN MICHAEL                      NaN                     761        1486
# BUCHANAN HAROLD G               248017                      23        1088
# BUTTS ROBERT H                  261516                     NaN         NaN
# BUY RICHARD B                   330546                    2333        3523
# CALGER CHRISTOPHER F            240189                    2188        2598
# CARTER REBECCA C                261809                     196         312
# CAUSEY RICHARD A                415189                    1585        1892
# CHAN RONNIE                        NaN                     NaN         NaN
# CHRISTODOULOU DIOMEDES             NaN                     NaN         NaN
# CLINE KENNETH W                    NaN                     NaN         NaN
# COLWELL WESLEY                  288542                    1132        1758
# CORDES WILLIAM R                   NaN                      58         764
# COX DAVID                       314288                      71         102
# CUMBERLAND MICHAEL S            184899                     NaN         NaN
# ...                                ...                     ...         ...
# SCRIMSHAW MATTHEW                  NaN                     NaN         NaN
# SHANKMAN JEFFREY A              304110                    1730        3221
# SHAPIRO RICHARD S               269076                    4527       15149
# SHARP VICTORIA T                248146                    2477        3136
# SHELBY REX                      211844                      91         225
# SHERRICK JEFFREY B                 NaN                     583         613
# SHERRIFF JOHN R                 428780                    2103        3187
# SKILLING JEFFREY K             1111258                    2042        3627
# STABLER FRANK                   239502                     NaN         NaN
# SULLIVAN-SHAKLOVITZ COLLEEN     162779                     NaN         NaN
# SUNDE MARTIN                    257486                    2565        2647
# TAYLOR MITCHELL S               265214                     300         533
# THE TRAVEL AGENCY IN THE PARK      NaN                     NaN         NaN
# THORN TERENCE H                 222093                      73         266
# TILNEY ELIZABETH A              247338                     379         460
# UMANOFF ADAM S                  288589                      41         111
# URQUHART JOHN A                    NaN                     NaN         NaN
# WAKEHAM JOHN                       NaN                     NaN         NaN
# WALLS JR ROBERT H               357091                     215         671
# WALTERS GARETH W                   NaN                     NaN         NaN
# WASAFF GEORGE                   259996                     337         400
# WESTFAHL RICHARD K               63744                     NaN         NaN
# WHALEY DAVID A                     NaN                     NaN         NaN
# WHALLEY LAWRENCE G              510364                    3920        6019
# WHITE JR THOMAS E               317543                     NaN         NaN
# WINOKUR JR. HERBERT S              NaN                     NaN         NaN
# WODRASKA JOHN                      NaN                     NaN         NaN
# WROBEL BRUCE                       NaN                     NaN         NaN
# YEAGER F SCOTT                  158403                     NaN         NaN
# YEAP SOON                          NaN                     NaN         NaN
#
#                               total_payments total_stock_value
# ALLEN PHILLIP K                      4484442           1729541
# BADUM JAMES P                         182466            257817
# BANNANTINE JAMES M                    916197           5243487
# BAXTER JOHN C                        5634343          10623258
# BAY FRANKLIN R                        827696             63014
# BAZELIDES PHILIP J                    860136           1599641
# BECK SALLY W                          969068            126027
# BELDEN TIMOTHY N                     5501630           1110705
# BELFER ROBERT                         102500            -44093
# BERBERIAN DAVID                       228474           2493616
# BERGSIEKER RICHARD P                  618850            659249
# BHATNAGAR SANJAY                    15456290               NaN
# BIBI PHILIPPE A                      2047593           1843816
# BLACHMAN JEREMY M                    2014835            954354
# BLAKE JR. NORMAN P                      1279               NaN
# BOWEN JR RAYMOND M                   2669589            252055
# BROWN MICHAEL                          49288               NaN
# BUCHANAN HAROLD G                    1054637           1014505
# BUTTS ROBERT H                       1271582            417619
# BUY RICHARD B                        2355702           3444470
# CALGER CHRISTOPHER F                 1639297            126027
# CARTER REBECCA C                      477557               NaN
# CAUSEY RICHARD A                     1868758           2502063
# CHAN RONNIE                              NaN               NaN
# CHRISTODOULOU DIOMEDES                   NaN           6077885
# CLINE KENNETH W                          NaN            189518
# COLWELL WESLEY                       1490344            698242
# CORDES WILLIAM R                         NaN           1038185
# COX DAVID                            1101393            495633
# CUMBERLAND MICHAEL S                  807956            207940
# ...                                      ...               ...
# SCRIMSHAW MATTHEW                        NaN            759557
# SHANKMAN JEFFREY A                   3038702           2072035
# SHAPIRO RICHARD S                    1057548            987001
# SHARP VICTORIA T                     1576511            494136
# SHELBY REX                           2003885           2493616
# SHERRICK JEFFREY B                       NaN           1832468
# SHERRIFF JOHN R                      4335388           3128982
# SKILLING JEFFREY K                   8682716          26093672
# STABLER FRANK                        1112087            511734
# SULLIVAN-SHAKLOVITZ COLLEEN           999356           1362375
# SUNDE MARTIN                         1545059            698920
# TAYLOR MITCHELL S                    1092663           3745048
# THE TRAVEL AGENCY IN THE PARK         362096               NaN
# THORN TERENCE H                       911453           4817796
# TILNEY ELIZABETH A                    399393           1168042
# UMANOFF ADAM S                       1130461               NaN
# URQUHART JOHN A                       228656               NaN
# WAKEHAM JOHN                          213071               NaN
# WALLS JR ROBERT H                    1798780           5898997
# WALTERS GARETH W                       87410           1030329
# WASAFF GEORGE                        1034395           2056427
# WESTFAHL RICHARD K                    762135            384930
# WHALEY DAVID A                           NaN             98718
# WHALLEY LAWRENCE G                   4677574           6079137
# WHITE JR THOMAS E                    1934359          15144123
# WINOKUR JR. HERBERT S                  84992               NaN
# WODRASKA JOHN                         189583               NaN
# WROBEL BRUCE                             NaN            139130
# YEAGER F SCOTT                        360300          11884758
# YEAP SOON                              55097            192758
#
# [145 rows x 21 columns]

# %%
enron_df.shape
# Out:
# (145, 21)

# %%
enron_df.describe()
# Out:
#        bonus deferral_payments deferred_income director_fees email_address  \
# count    145               145             145           145           145
# unique    41                39              44            17           112
# top      NaN               NaN             NaN           NaN           NaN
# freq      64               107              97           129            34
#
#        exercised_stock_options expenses from_messages from_poi_to_this_person  \
# count                      145      145           145                     145
# unique                     101       94            65                      58
# top                        NaN      NaN           NaN                     NaN
# freq                        44       51            59                      59
#
#        from_this_person_to_poi  ... long_term_incentive other    poi  \
# count                      145  ...                 145   145    145
# unique                      42  ...                  52    92      2
# top                        NaN  ...                 NaN   NaN  False
# freq                        59  ...                  80    53    127
#
#        restricted_stock restricted_stock_deferred salary  \
# count               145                       145    145
# unique               97                        18     94
# top                 NaN                       NaN    NaN
# freq                 36                       128     51
#
#        shared_receipt_with_poi to_messages total_payments total_stock_value
# count                      145         145            145               145
# unique                      84          87            125               124
# top                        NaN         NaN            NaN               NaN
# freq                        59          59             21                20
#
# [4 rows x 21 columns]

# %%
#Check and take care of "NaN"
# Convert to numpy nan
enron_df.replace(to_replace='NaN', value=numpy.nan, inplace=True)

# %%
enron_df.describe()
# Out:
#               bonus  deferral_payments  deferred_income  director_fees  \
# count  8.100000e+01       3.800000e+01     4.800000e+01      16.000000
# mean   1.201773e+06       8.416025e+05    -5.810498e+05   89822.875000
# std    1.441679e+06       1.289323e+06     9.420764e+05   41112.700735
# min    7.000000e+04      -1.025000e+05    -3.504386e+06    3285.000000
# 25%    4.250000e+05       7.964450e+04    -6.112092e+05   83674.500000
# 50%    7.500000e+05       2.210635e+05    -1.519270e+05  106164.500000
# 75%    1.200000e+06       8.672112e+05    -3.792600e+04  112815.000000
# max    8.000000e+06       6.426990e+06    -8.330000e+02  137864.000000
#
#        exercised_stock_options       expenses  from_messages  \
# count             1.010000e+02      94.000000      86.000000
# mean              2.959559e+06   54192.010638     608.790698
# std               5.499450e+06   46108.377454    1841.033949
# min               3.285000e+03     148.000000      12.000000
# 25%               5.067650e+05   22479.000000      22.750000
# 50%               1.297049e+06   46547.500000      41.000000
# 75%               2.542813e+06   78408.500000     145.500000
# max               3.434838e+07  228763.000000   14368.000000
#
#        from_poi_to_this_person  from_this_person_to_poi  loan_advances  \
# count                86.000000                86.000000   3.000000e+00
# mean                 64.895349                41.232558   2.797500e+07
# std                  86.979244               100.073111   4.638256e+07
# min                   0.000000                 0.000000   4.000000e+05
# 25%                  10.000000                 1.000000   1.200000e+06
# 50%                  35.000000                 8.000000   2.000000e+06
# 75%                  72.250000                24.750000   4.176250e+07
# max                 528.000000               609.000000   8.152500e+07
#
#        long_term_incentive         other  restricted_stock  \
# count         6.500000e+01  9.200000e+01      1.090000e+02
# mean          7.464912e+05  4.652767e+05      1.147424e+06
# std           8.629174e+05  1.389719e+06      2.249770e+06
# min           6.922300e+04  2.000000e+00     -2.604490e+06
# 25%           2.750000e+05  1.209000e+03      2.520550e+05
# 50%           4.221580e+05  5.198450e+04      4.410960e+05
# 75%           8.318090e+05  3.575772e+05      9.850320e+05
# max           5.145434e+06  1.035973e+07      1.476169e+07
#
#        restricted_stock_deferred        salary  shared_receipt_with_poi  \
# count               1.700000e+01  9.400000e+01                86.000000
# mean                6.218928e+05  2.840875e+05              1176.465116
# std                 3.845528e+06  1.771311e+05              1178.317641
# min                -1.787380e+06  4.770000e+02                 2.000000
# 25%                -3.298250e+05  2.118020e+05               249.750000
# 50%                -1.402640e+05  2.587410e+05               740.500000
# 75%                -7.241900e+04  3.086065e+05              1888.250000
# max                 1.545629e+07  1.111258e+06              5521.000000
#
#         to_messages  total_payments  total_stock_value
# count     86.000000    1.240000e+02       1.250000e+02
# mean    2073.860465    2.623421e+06       3.352073e+06
# std     2582.700981    9.488106e+06       6.532883e+06
# min       57.000000    1.480000e+02      -4.409300e+04
# 25%      541.250000    3.863802e+05       4.941360e+05
# 50%     1211.000000    1.100246e+06       1.095040e+06
# 75%     2634.750000    2.084663e+06       2.606763e+06
# max    15149.000000    1.035598e+08       4.911008e+07

# %%
#Create new features 'from_poi_ratio' & 'to_poi_ratio'

enron_df['from_poi_ratio'] = enron_df['from_poi_to_this_person']/enron_df['to_messages']
enron_df['to_poi_ratio'] = enron_df['from_this_person_to_poi']/enron_df['from_messages']

# %%
#Dataframe now shows the new features

enron_df.describe()
# Out:
#               bonus  deferral_payments  deferred_income  director_fees  \
# count  8.100000e+01       3.800000e+01     4.800000e+01      16.000000
# mean   1.201773e+06       8.416025e+05    -5.810498e+05   89822.875000
# std    1.441679e+06       1.289323e+06     9.420764e+05   41112.700735
# min    7.000000e+04      -1.025000e+05    -3.504386e+06    3285.000000
# 25%    4.250000e+05       7.964450e+04    -6.112092e+05   83674.500000
# 50%    7.500000e+05       2.210635e+05    -1.519270e+05  106164.500000
# 75%    1.200000e+06       8.672112e+05    -3.792600e+04  112815.000000
# max    8.000000e+06       6.426990e+06    -8.330000e+02  137864.000000
#
#        exercised_stock_options       expenses  from_messages  \
# count             1.010000e+02      94.000000      86.000000
# mean              2.959559e+06   54192.010638     608.790698
# std               5.499450e+06   46108.377454    1841.033949
# min               3.285000e+03     148.000000      12.000000
# 25%               5.067650e+05   22479.000000      22.750000
# 50%               1.297049e+06   46547.500000      41.000000
# 75%               2.542813e+06   78408.500000     145.500000
# max               3.434838e+07  228763.000000   14368.000000
#
#        from_poi_to_this_person  from_this_person_to_poi  loan_advances  ...  \
# count                86.000000                86.000000   3.000000e+00  ...
# mean                 64.895349                41.232558   2.797500e+07  ...
# std                  86.979244               100.073111   4.638256e+07  ...
# min                   0.000000                 0.000000   4.000000e+05  ...
# 25%                  10.000000                 1.000000   1.200000e+06  ...
# 50%                  35.000000                 8.000000   2.000000e+06  ...
# 75%                  72.250000                24.750000   4.176250e+07  ...
# max                 528.000000               609.000000   8.152500e+07  ...
#
#               other  restricted_stock  restricted_stock_deferred  \
# count  9.200000e+01      1.090000e+02               1.700000e+01
# mean   4.652767e+05      1.147424e+06               6.218928e+05
# std    1.389719e+06      2.249770e+06               3.845528e+06
# min    2.000000e+00     -2.604490e+06              -1.787380e+06
# 25%    1.209000e+03      2.520550e+05              -3.298250e+05
# 50%    5.198450e+04      4.410960e+05              -1.402640e+05
# 75%    3.575772e+05      9.850320e+05              -7.241900e+04
# max    1.035973e+07      1.476169e+07               1.545629e+07
#
#              salary  shared_receipt_with_poi   to_messages  total_payments  \
# count  9.400000e+01                86.000000     86.000000    1.240000e+02
# mean   2.840875e+05              1176.465116   2073.860465    2.623421e+06
# std    1.771311e+05              1178.317641   2582.700981    9.488106e+06
# min    4.770000e+02                 2.000000     57.000000    1.480000e+02
# 25%    2.118020e+05               249.750000    541.250000    3.863802e+05
# 50%    2.587410e+05               740.500000   1211.000000    1.100246e+06
# 75%    3.086065e+05              1888.250000   2634.750000    2.084663e+06
# max    1.111258e+06              5521.000000  15149.000000    1.035598e+08
#
#        total_stock_value  from_poi_ratio  to_poi_ratio
# count       1.250000e+02       86.000000     86.000000
# mean        3.352073e+06        0.037963      0.184055
# std         6.532883e+06        0.040544      0.210610
# min        -4.409300e+04        0.000000      0.000000
# 25%         4.941360e+05        0.009200      0.012421
# 50%         1.095040e+06        0.025845      0.100574
# 75%         2.606763e+06        0.056089      0.272039
# max         4.911008e+07        0.217341      1.000000
#
# [8 rows x 21 columns]

# %%
#Show correlation between 'POI" and the different features'

corr = enron_df.corr()
print(corr['poi'])
# Out:
# bonus                        0.302384
# deferral_payments           -0.098428
# deferred_income             -0.265698
# director_fees                     NaN
# exercised_stock_options      0.503551
# expenses                     0.060292
# from_messages               -0.074308
# from_poi_to_this_person      0.167722
# from_this_person_to_poi      0.112940
# loan_advances                0.999851
# long_term_incentive          0.254723
# other                        0.120510
# poi                          1.000000
# restricted_stock             0.224814
# restricted_stock_deferred         NaN
# salary                       0.264976
# shared_receipt_with_poi      0.228313
# to_messages                  0.058954
# total_payments               0.230692
# total_stock_value            0.366462
# from_poi_ratio               0.104406
# to_poi_ratio                 0.339938
# Name: poi, dtype: float64

# %%
#Feature Selection - Round 1

from time import time
features_list = ["poi", "salary", "bonus", "from_poi_ratio", "to_poi_ratio",
                 'deferral_payments', 'total_payments', 'loan_advances', 'restricted_stock_deferred',
                 'deferred_income', 'total_stock_value', 'expenses', 'exercised_stock_options',
                 'long_term_incentive', 'shared_receipt_with_poi', 'restricted_stock', 'director_fees']
data = featureFormat(enron_data, features_list)

### split into labels and features (this line assumes that the first
### feature in the array is the label, which is why "poi" must always
### be first in features_list
labels, features = targetFeatureSplit(data)

### split data into training and testing datasets
from sklearn.model_selection import train_test_split
features_train, features_test, labels_train, labels_test = train_test_split(features, labels, test_size=0.1, random_state=42)

t0 = time()

from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier()
clf = clf.fit(features_train, labels_train)
pred = clf.predict(features_test)
print "Accuracy:", clf.score(features_test, labels_test)

print "Decision tree algorithm time:", round(time()-t0, 3), "s"

# Find the top feature in the decision tree and its relative importance

importances = clf.feature_importances_
import numpy as np
indices = np.argsort(importances)[::-1]
print 'Feature Ranking: '
for i in range(17):
    print "{} feature {} ({})".format(i+1,features_list[i+1],importances[indices[i]])
# Out:
# error: key  from_poi_ratio  not present
# TypeErrorTraceback (most recent call last)
# <ipython-input-28-e3b297771e66> in <module>()
#      11 ### feature in the array is the label, which is why "poi" must always
#      12 ### be first in features_list
# ---> 13 labels, features = targetFeatureSplit(data)
#      14
#      15 ### split data into training and testing datasets
#
# D:/Desktop/WGU Projects/data_analyst_nanodegree/machine_learning/ud120-projects-master/tools/feature_format.pyc in targetFeatureSplit(data)
#     118     target = []
#     119     features = []
# --> 120     for item in data:
#     121         target.append( item[0] )
#     122         features.append( item[1:] )
#
# TypeError: 'NoneType' object is not iterable

# %%
#Feature Selection - Round 2
# Kept only the top 10 from the list above

from time import time
features_list = ["poi", 'salary', 'deferral_payments', 'total_payments', 'loan_advances', 'bonus', 'restricted_stock_deferred',
                 'deferred_income', 'total_stock_value', 'expenses', 'exercised_stock_options']
data = featureFormat(enron_data, features_list)

### split into labels and features (this line assumes that the first
### feature in the array is the label, which is why "poi" must always
### be first in features_list
labels, features = targetFeatureSplit(data)

### split data into training and testing datasets
from sklearn.model_selection import train_test_split
features_train, features_test, labels_train, labels_test = train_test_split(features, labels, test_size=0.1, random_state=42)

t0 = time()

from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier()
clf = clf.fit(features_train, labels_train)
pred = clf.predict(features_test)
print "Accuracy:", clf.score(features_test, labels_test)

print "Decision tree algorithm time:", round(time()-t0, 3), "s"

# Find the top feature in the decision tree and its relative importance

importances = clf.feature_importances_
import numpy as np
indices = np.argsort(importances)[::-1]
print 'Feature Ranking: '
for i in range(10):
    print "{} feature {} ({})".format(i+1,features_list[i+1],importances[indices[i]])
# Out:
# Accuracy: 0.8
# Decision tree algorithm time: 0.002 s
# Feature Ranking:
# 1 feature salary (0.261245367712)
# 2 feature deferral_payments (0.17727793832)
# 3 feature total_payments (0.146356434954)
# 4 feature loan_advances (0.144261508951)
# 5 feature bonus (0.13735581189)
# 6 feature restricted_stock_deferred (0.068677905945)
# 7 feature deferred_income (0.0648250322278)
# 8 feature total_stock_value (0.0)
# 9 feature expenses (0.0)
# 10 feature exercised_stock_options (0.0)

# %%
#Feature Selection - Round 3
# Kept only the top 5 from the list above

from time import time
features_list = ["poi", 'salary', 'deferral_payments', 'total_payments', 'loan_advances', 'bonus']
data = featureFormat(enron_data, features_list)

### split into labels and features (this line assumes that the first
### feature in the array is the label, which is why "poi" must always
### be first in features_list
labels, features = targetFeatureSplit(data)

### split data into training and testing datasets
from sklearn.model_selection import train_test_split
features_train, features_test, labels_train, labels_test = train_test_split(features, labels, test_size=0.1, random_state=42)

t0 = time()

from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier()
clf = clf.fit(features_train, labels_train)
pred = clf.predict(features_test)
print "Accuracy:", clf.score(features_test, labels_test)

print "Decision tree algorithm time:", round(time()-t0, 3), "s"

# Find the top feature in the decision tree and its relative importance

importances = clf.feature_importances_
import numpy as np
indices = np.argsort(importances)[::-1]
print 'Feature Ranking: '
for i in range(5):
    print "{} feature {} ({})".format(i+1,features_list[i+1],importances[indices[i]])
# Out:
# Accuracy: 0.7692307692307693
# Decision tree algorithm time: 0.002 s
# Feature Ranking:
# 1 feature salary (0.456890701836)
# 2 feature deferral_payments (0.239336449536)
# 3 feature total_payments (0.237089494436)
# 4 feature loan_advances (0.0666833541927)
# 5 feature bonus (0.0)

# %%
numeric_df = (enron_df-numeric_df.min())/(enron_df.max()-numeric_df.min())

from sklearn.feature_selection import SelectKBest
selector = SelectKBest()
selector.fit(numeric_df,poi.tolist())
scores = {numeric_df.columns[i]:selector.scores_[i] for i in range(len(numeric_df.columns))}
sorted_features = sorted(scores,key=scores.get, reverse=True)
for feature in sorted_features:
    print('Feature %s has value %f'%(feature,scores[feature]))
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-196-c2412d965604> in <module>()
# ----> 1 numeric_df = (enron_df-numeric_df.min())/(enron_df.max()-numeric_df.min())
#       2
#       3 from sklearn.feature_selection import SelectKBest
#       4 selector = SelectKBest()
#       5 selector.fit(numeric_df,poi.tolist())
#
# NameError: name 'numeric_df' is not defined

# %%
#Naive Bayes
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score

features_list = ["poi", 'salary', 'deferral_payments', 'total_payments', 'loan_advances', 'bonus']

t0 = time()

clf = GaussianNB()
clf.fit(features_train, labels_train)
pred = clf.predict(features_test)
accuracy = accuracy_score(pred,labels_test)
precision = precision_score(labels_test, pred)
recall = recall_score(labels_test, pred)

print "Naive Bayes Accuracy :", accuracy
print 'Precision :', precision
print 'Recall :', recall
# Out:
# Naive Bayes Accuracy : 0.3448275862068966
# Precision : 0.3076923076923077
# Recall : 0.8888888888888888

# %%
#SVM

from sklearn import svm
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score


clf = SVC(kernel = 'linear', C=1)
clf.fit(features_train, labels_train)
pred = clf.predict(features_test)
accuracy = accuracy_score(pred,labels_test)
precision = precision_score(labels_test, pred)
recall = recall_score(labels_test, pred)


print "SVM Accuracy :", accuracy
print 'Precision :', precision
print 'Recall :', recall

# %%
#Decision Tree

from sklearn import tree

clf = tree.DecisionTreeClassifier()
clf = clf.fit(features_train, labels_train)
pred = clf.predict(features_test)
accuracy = accuracy_score(pred,labels_test)
precision = precision_score(labels_test, pred)
recall = recall_score(labels_test, pred)

print "Decision Tree Accuracy :", accuracy
print 'Precision :', precision
print 'Recall :', recall
# Out:
# Decision Tree Accuracy : 0.6551724137931034
# Precision : 0.4
# Recall : 0.2222222222222222

# %%
from sklearn.neighbors import NearestNeighbors
from sklearn import neighbors
import numpy as np

clf = neighbors.KNeighborsClassifier()
clf = clf.fit(features_train, labels_train)
pred = clf.predict(features_test)
accuracy = accuracy_score(pred,labels_test)
precision = precision_score(labels_test, pred)
recall = recall_score(labels_test, pred)


print "KNN Accuracy :", accuracy
print 'Precision :', precision
print 'Recall :', recall

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier()
clf = clf.fit(features_train, labels_train)
pred = clf.predict(features_test)
accuracy = accuracy_score(pred,labels_test)
precision = precision_score(labels_test, pred)
recall = recall_score(labels_test, pred)


print "Random Forest Accuracy :", accuracy
print 'Precision :', precision
print 'Recall :', recall

# %%
from sklearn.ensemble import AdaBoostClassifier

clf = AdaBoostClassifier()
clf = clf.fit(features_train, labels_train)
pred = clf.predict(features_test)
accuracy = accuracy_score(pred,labels_test)
precision = precision_score(labels_test, pred)
recall = recall_score(labels_test, pred)


print "AdaBoost Accuracy :", accuracy
print 'Precision :', precision
print 'Recall :', recall
